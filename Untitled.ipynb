# %%
import sys
from PyQt5 import QtWidgets as qtw
from PyQt5 import QtCore as qtc
from PyQt5 import QtGui as qtg

from PyQt5.QtWidgets import (QTableWidget, QTableWidgetItem, QTableView)
from PyQt5.QtCore import QAbstractTableModel, Qt, QModelIndex

import seaborn as sns
from matplotlib.backends.backend_qt5agg import FigureCanvas
from matplotlib.figure import Figure

import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn import tree
from sklearn.linear_model import SGDClassifier
from sklearn import svm
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier

from tablexx import PandasModel
from classifier_tab import ClassifierTab
from feature_tab import FeatureExtractionTab
from test_section import TestSection

# knn_params = {
#     "weight": 1,
#     "algorithm": "",
#     "leaf": 1,
#     "p": 1,
#     "neighbors": 1
# }

naive_bayes_params = {
    "fit_prior": True,
    "alpha": 1,
}
naive_bayes_type = MultinomialNB

train_labels = []
train_msg = []

feature_params = {}

count_vect = {}
train_counts = {}
training_words = {}

classifier = {}


class MainWindow(qtw.QWidget):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

        selected_classifier = qtc.pyqtSignal()
        knn_params = qtc.pyqtSignal(dict)

        sns.set_theme(style="darkgrid")

        self.training_upload_section()
        # TestSection(self)
        self.setUpMainTab()
        self.widget_layout()

        self.show()

    def training_upload_section(self):
        self.textedit = qtw.QTextEdit()

        self.info_text = qtw.QLabel("<h3>Upload Training Data Set<h3>")
        self.info_text.setStyleSheet("""
            font-size: 24px;
        """)

        self.upload_button = qtw.QPushButton('Upload')
        # self.upload_button.setFixedSize(100, 40)
        self.upload_button.setStyleSheet("""
            border-radius: 45px;
            background-color: #2ABf9E;
            padding: 10px;
            font-size: 18px;
            color: white;
        """)
        self.upload_button.clicked.connect(self.open)

        self.create_table()


    def create_table(self):
        self.traintableView = QTableWidget()
        self.traintableView.setFixedHeight(150)
        self.traintableView.setColumnCount(2)
        self.traintableView.setRowCount(10)
        self.traintableView.setHorizontalHeaderLabels(["Label", "Review"])
        self.traintableView.horizontalHeader().setStretchLastSection(True)


    def widget_layout(self):
        layout = qtw.QHBoxLayout()

        self.left_layout = qtw.QVBoxLayout()
        right_layout = qtw.QVBoxLayout()

        self.left_layout.addWidget(self.info_text)
        self.left_layout.addWidget(self.traintableView)
        self.left_layout.addWidget(self.upload_button)

        self.left_layout.addWidget(self.tabwidget)

        # right_layout.addWidget(TestSection(self))

        left_widget = qtw.QWidget()
        left_widget.setLayout(self.left_layout)

        # right_widget = qtw.QWidget()
        # right_widget.setLayout(right_layout)

        self.test_section = TestSection(self)

        layout.addWidget(left_widget)
        layout.addWidget(self.test_section)

        # main_widget = qtw.QWidget()
        # main_widget.setLayout(layout)

        self.setLayout(layout)
        # self.setCentralWidget(main_widget)


    def setUpMainTab(self):
        self.tabwidget = qtw.QTabWidget()
        self.featureTab = FeatureExtractionTab(self)
        self.featureTab.submitted.connect(self.handle_feature_params)

        self.classifierTab = ClassifierTab(self)
        self.classifierTab.naive_bayes_submitted.connect(self.handle_naive_bayes_submit)
        self.classifierTab.knn_submitted.connect(self.handle_knn_submit)


        self.tabwidget.addTab(self.featureTab, "Feature extraction")
        self.tabwidget.addTab(self.classifierTab, "Classifiers")

        self.tabwidget.tabBar().setTabTextColor(0, Qt.black)
        self.tabwidget.tabBar().setTabTextColor(1, Qt.black)
        
        
    def open(self):
        filename, _ = qtw.QFileDialog.getOpenFileName()
        if filename:
            file = open(filename, 'r')
            lines = file.readlines()
            i = 0
            train_labels.clear()
            train_msg.clear()
            for line in lines:
                # print(line)
                splitLine = line.split('\t')
                item_label = splitLine[0]
                item_msg = splitLine[2]
                train_labels.append(item_label)
                train_msg.append(item_msg)
                if i < 10:
                    self.traintableView.setItem(i, 0, QTableWidgetItem(item_label))
                    self.traintableView.setItem(i, 1, QTableWidgetItem(item_msg))
                i += 1
                # if i > 9:
                #     break

            # if len(train_msg):
                


    def train_dataset(self):
        # print(feature_params)
        count_vect['value'] = CountVectorizer(**feature_params)
        # print(count_vect)
        train_counts['value'] = count_vect['value'].fit_transform(train_msg)
        training_words['value'] = count_vect['value'].get_feature_names()
        print("train_counts", train_counts)
        # print(training_words)


        # self.h_layout = qtw.QHBoxLayout()
        # self.h_layout.setSpacing(4)
        # self.h_layout.setContentsMargins(4, 4, 4, 4)
        # feature_widget = qtw.QWidget()
        # feature_widget.setLayout(self.h_layout)

        # gh = qtw.Qtwev

        # for word in training_words:
        #     self.add_tag_to_bar(word)
        
        # self.left_layout.addWidget(feature_widget)

    def add_tag_to_bar(self, text):
        label = qtw.QLabel(text)
        label.setStyleSheet('border:1px solid rgb(192, 192, 192); border-radius: 4px;')
        # label.setFixedHeight(16)
        label.setFixedSize(50, 20)
        self.h_layout.addWidget(label)
        label.setSizePolicy(qtw.QSizePolicy.Maximum, qtw.QSizePolicy.Preferred)
        # self.h_layout.addWidget(tag)


    @qtc.pyqtSlot(str, str, bool, bool, str, str, str, str, str, str)
    def handle_feature_params(
        self,
        strip_accents,
        analyzer,
        lowercase,
        binary,
        stop_words,
        token_pattern,
        ngram_range,
        max_df,
        min_df,
        max_features
        ):
        if (strip_accents):
            feature_params['strip_accents'] = strip_accents
        if (analyzer):
            feature_params['analyzer'] = analyzer
        feature_params['lowercase'] = lowercase
        feature_params['binary'] = binary
        if stop_words:
            feature_params['stop_words'] = stop_words
        if token_pattern:
            feature_params['token_pattern'] = token_pattern
        if ngram_range:
            (min, max) = ngram_range.split(',')
            feature_params['ngram_range'] = (int(min), int(max))
        if max_df:
            feature_params['max_df'] = max_df
        if min_df:
            feature_params['min_df'] = min_df
        if max_features:
            feature_params['max_features'] = max_features
        
        self.train_dataset()


    @qtc.pyqtSlot(str, bool, str)
    def handle_naive_bayes_submit(
        self,
        type,
        fit_prior,
        alpha,
        ):
        # naive_bayes_type = {'Complement': 1, 'Multinomial': 0}[type]
        naive_bayes_params['fit_prior'] = fit_prior
        if alpha:
            naive_bayes_params['alpha'] = float(alpha)

        # print(naive_bayes_type)
        # print(naive_bayes_params)
        if (type == 'Complement'):
            classifier['value'] = ComplementNB(**naive_bayes_params)
        else:
            classifier['value'] = MultinomialNB(**naive_bayes_params)

        print("----------")

        classifier['value'].fit(train_counts['value'], train_labels)

        self.update_test_section_data()
        
        
    @qtc.pyqtSlot(str, str, str, str, str)
    def handle_knn_submit(
        self,
        weights,
        algorithm,
        n_neighbors,
        leaf_size,
        p,
        ):
        # naive_bayes_type = {'Complement': 1, 'Multinomial': 0}[type]
        knn_params = {}
        if n_neighbors:
            knn_params['n_neighbors'] = int(n_neighbors)
        knn_params['weights'] = weights
        knn_params['algorithm'] = algorithm
        if leaf_size:
            knn_params['leaf_size'] = int(leaf_size)

        print("knn_params -----", knn_params)
        if p:
            knn_params['p'] = int(p)
            
        classifier['value'] = KNeighborsClassifier(**knn_params)

        print("classifier value----------", classifier['value'])

        classifier['value'].fit(train_counts['value'], train_labels)

        self.update_test_section_data()



    def update_test_section_data(self):
        self.test_section.update_variables(
            train_labels,
            train_msg,
            count_vect,
            train_counts,
            training_words,
            classifier
        )



if __name__ == '__main__':
    app = qtw.QApplication(sys.argv)
    w = MainWindow()
    w.setFixedWidth(1200)
    w.setFixedHeight(900)
    # w.setGeometry(0, 0, 1200, 400)
    sys.exit(app.exec_())
# Out:
# 1
#
# word
# train_counts {'value': <4000x9647 sparse matrix of type '<class 'numpy.int64'>'
# 	with 146153 stored elements in Compressed Sparse Row format>}
# Complement
# ----------
#
#  ComplementNB(alpha=1)
# {'1': {'precision': 0.5200642054574639, 'recall': 0.5355371900826447, 'f1-score': 0.5276872964169382, 'support': 605}, '2': {'precision': 0.26422764227642276, 'recall': 0.15151515151515152, 'f1-score': 0.19259259259259257, 'support': 429}, '3': {'precision': 0.84797189396359, 'recall': 0.8951449763991909, 'f1-score': 0.8709201246514681, 'support': 2966}, 'accuracy': 0.761, 'macro avg': {'precision': 0.5440879138991589, 'recall': 0.5273991059989956, 'f1-score': 0.5304000045536662, 'support': 4000}, 'weighted avg': {'precision': 0.7357692850835897, 'recall': 0.761, 'f1-score': 0.746255531567681, 'support': 4000}}
# length of 3 3131 246 623
# -------       labels   category
# 0          3  Predicted
# 1          3  Predicted
# 2          3  Predicted
# 3          3  Predicted
# 4          3  Predicted
# ...      ...        ...
# 7995       3     Actual
# 7996       3     Actual
# 7997       3     Actual
# 7998       3     Actual
# 7999       3     Actual
#
# [8000 rows x 2 columns]
# Multinomial
# ----------
#
#  MultinomialNB(alpha=1)
# {'1': {'precision': 0.6527331189710611, 'recall': 0.33553719008264465, 'f1-score': 0.443231441048035, 'support': 605}, '2': {'precision': 0.23529411764705882, 'recall': 0.027972027972027972, 'f1-score': 0.049999999999999996, 'support': 429}, '3': {'precision': 0.7919186366135239, 'recall': 0.971341874578557, 'f1-score': 0.8725015142337977, 'support': 2966}, 'accuracy': 0.774, 'macro avg': {'precision': 0.5599819577438813, 'recall': 0.44495036421107653, 'f1-score': 0.4552443184272776, 'support': 4000}, 'weighted avg': {'precision': 0.7111688474109481, 'recall': 0.774, 'f1-score': 0.7193611282628762, 'support': 4000}}
# length of 3 3638 51 311
# -------       labels   category
# 0          3  Predicted
# 1          3  Predicted
# 2          3  Predicted
# 3          3  Predicted
# 4          3  Predicted
# ...      ...        ...
# 7995       3     Actual
# 7996       3     Actual
# 7997       3     Actual
# 7998       3     Actual
# 7999       3     Actual
#
# [8000 rows x 2 columns]
# knn_params ----- {'n_neighbors': 9, 'weights': 'uniform', 'algorithm': 'auto'}
# classifier value---------- KNeighborsClassifier(n_neighbors=9)
#
#  KNeighborsClassifier(n_neighbors=9)
# {'1': {'precision': 0.4351145038167939, 'recall': 0.1884297520661157, 'f1-score': 0.2629757785467128, 'support': 605}, '2': {'precision': 0.14285714285714285, 'recall': 0.006993006993006993, 'f1-score': 0.013333333333333332, 'support': 429}, '3': {'precision': 0.7680925477535647, 'recall': 0.9625758597437627, 'f1-score': 0.8544067035762382, 'support': 2966}, 'accuracy': 0.743, 'macro avg': {'precision': 0.4486880648091671, 'recall': 0.38599953960096184, 'f1-score': 0.3769052718187614, 'support': 4000}, 'weighted avg': {'precision': 0.6506731214329868, 'recall': 0.743, 'f1-score': 0.6747476572069708, 'support': 4000}}
# length of 3 3717 21 262
# -------       labels   category
# 0          3  Predicted
# 1          3  Predicted
# 2          3  Predicted
# 3          3  Predicted
# 4          3  Predicted
# ...      ...        ...
# 7995       3     Actual
# 7996       3     Actual
# 7997       3     Actual
# 7998       3     Actual
# 7999       3     Actual
#
# [8000 rows x 2 columns]
# knn_params ----- {'n_neighbors': 3, 'weights': 'uniform', 'algorithm': 'auto'}
# classifier value---------- KNeighborsClassifier(n_neighbors=3)
#
#  KNeighborsClassifier(n_neighbors=3)
# {'1': {'precision': 0.2894736842105263, 'recall': 0.23636363636363636, 'f1-score': 0.26023657870791633, 'support': 605}, '2': {'precision': 0.1588235294117647, 'recall': 0.06293706293706294, 'f1-score': 0.09015025041736227, 'support': 429}, '3': {'precision': 0.7691846522781774, 'recall': 0.8651382333108564, 'f1-score': 0.8143446524912726, 'support': 2966}, 'accuracy': 0.684, 'macro avg': {'precision': 0.4058272886334895, 'recall': 0.38814631087051854, 'f1-score': 0.3882438272055171, 'support': 4000}, 'weighted avg': {'precision': 0.6311671379305224, 'recall': 0.684, 'f1-score': 0.6528659567091131, 'support': 4000}}
# length of 3 3336 170 494
# -------       labels   category
# 0          3  Predicted
# 1          1  Predicted
# 2          3  Predicted
# 3          3  Predicted
# 4          3  Predicted
# ...      ...        ...
# 7995       3     Actual
# 7996       3     Actual
# 7997       3     Actual
# 7998       3     Actual
# 7999       3     Actual
#
# [8000 rows x 2 columns]
# knn_params ----- {'n_neighbors': 13, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 70}
# classifier value---------- KNeighborsClassifier(leaf_size=70, n_neighbors=13)
#
#  KNeighborsClassifier(leaf_size=70, n_neighbors=13)
# {'1': {'precision': 0.47019867549668876, 'recall': 0.11735537190082644, 'f1-score': 0.18783068783068785, 'support': 605}, '2': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 429}, '3': {'precision': 0.7585219880301848, 'recall': 0.9828051247471342, 'f1-score': 0.8562197092084006, 'support': 2966}, 'accuracy': 0.7465, 'macro avg': {'precision': 0.4095735545089578, 'recall': 0.3667201655493202, 'f1-score': 0.34801679901302945, 'support': 4000}, 'weighted avg': {'precision': 0.6335616037932561, 'recall': 0.7465, 'f1-score': 0.6632963059124205, 'support': 4000}}
# length of 3 3843 6 151
# -------       labels   category
# 0          3  Predicted
# 1          3  Predicted
# 2          3  Predicted
# 3          3  Predicted
# 4          3  Predicted
# ...      ...        ...
# 7995       3     Actual
# 7996       3     Actual
# 7997       3     Actual
# 7998       3     Actual
# 7999       3     Actual
#
# [8000 rows x 2 columns]
# knn_params ----- {'n_neighbors': 15, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 70}
# classifier value---------- KNeighborsClassifier(leaf_size=70, n_neighbors=15)
#
#  KNeighborsClassifier(leaf_size=70, n_neighbors=15)
# {'1': {'precision': 0.5247524752475248, 'recall': 0.08760330578512397, 'f1-score': 0.1501416430594901, 'support': 605}, '2': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 429}, '3': {'precision': 0.7539132666153452, 'recall': 0.9905596763317599, 'f1-score': 0.8561853416873089, 'support': 2966}, 'accuracy': 0.74775, 'macro avg': {'precision': 0.42622191395429, 'recall': 0.35938766070562794, 'f1-score': 0.335442328248933, 'support': 4000}, 'weighted avg': {'precision': 0.6383954990764665, 'recall': 0.74775, 'f1-score': 0.6575703543738874, 'support': 4000}}
# length of 3 3897 2 101
# -------       labels   category
# 0          3  Predicted
# 1          3  Predicted
# 2          3  Predicted
# 3          3  Predicted
# 4          3  Predicted
# ...      ...        ...
# 7995       3     Actual
# 7996       3     Actual
# 7997       3     Actual
# 7998       3     Actual
# 7999       3     Actual
#
# [8000 rows x 2 columns]
# knn_params ----- {'n_neighbors': 8, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 70}
# classifier value---------- KNeighborsClassifier(leaf_size=70, n_neighbors=8)
#
#  KNeighborsClassifier(leaf_size=70, n_neighbors=8)
# {'1': {'precision': 0.3512064343163539, 'recall': 0.21652892561983472, 'f1-score': 0.26789366053169733, 'support': 605}, '2': {'precision': 0.1951219512195122, 'recall': 0.018648018648018648, 'f1-score': 0.03404255319148936, 'support': 429}, '3': {'precision': 0.7710540992749582, 'recall': 0.9322319622387053, 'f1-score': 0.8440170940170941, 'support': 2966}, 'accuracy': 0.726, 'macro avg': {'precision': 0.4391274949369414, 'recall': 0.3891363021688529, 'f1-score': 0.38198443591342696, 'support': 4000}, 'weighted avg': {'precision': 0.6457834170710226, 'recall': 0.726, 'f1-score': 0.6700086551988818, 'support': 4000}}
# length of 3 3586 41 373
# -------       labels   category
# 0          3  Predicted
# 1          3  Predicted
# 2          3  Predicted
# 3          3  Predicted
# 4          3  Predicted
# ...      ...        ...
# 7995       3     Actual
# 7996       3     Actual
# 7997       3     Actual
# 7998       3     Actual
# 7999       3     Actual
#
# [8000 rows x 2 columns]
# knn_params ----- {'n_neighbors': 8, 'weights': 'distance', 'algorithm': 'auto', 'leaf_size': 70}
# classifier value---------- KNeighborsClassifier(leaf_size=70, n_neighbors=8, weights='distance')
#
#  KNeighborsClassifier(leaf_size=70, n_neighbors=8, weights='distance')
# {'1': {'precision': 0.4581497797356828, 'recall': 0.171900826446281, 'f1-score': 0.25, 'support': 605}, '2': {'precision': 0.16666666666666666, 'recall': 0.011655011655011656, 'f1-score': 0.02178649237472767, 'support': 429}, '3': {'precision': 0.7662302965535667, 'recall': 0.9669588671611599, 'f1-score': 0.854970934565509, 'support': 2966}, 'accuracy': 0.74425, 'macro avg': {'precision': 0.463682247651972, 'recall': 0.3835049017541508, 'f1-score': 0.37558580898007893, 'support': 4000}, 'weighted avg': {'precision': 0.6553299190794918, 'recall': 0.74425, 'f1-score': 0.6741100492875145, 'support': 4000}}
# length of 3 3743 30 227
# -------       labels   category
# 0          3  Predicted
# 1          3  Predicted
# 2          3  Predicted
# 3          3  Predicted
# 4          3  Predicted
# ...      ...        ...
# 7995       3     Actual
# 7996       3     Actual
# 7997       3     Actual
# 7998       3     Actual
# 7999       3     Actual
#
# [8000 rows x 2 columns]
# knn_params ----- {'n_neighbors': 12, 'weights': 'distance', 'algorithm': 'auto', 'leaf_size': 70}
# classifier value---------- KNeighborsClassifier(leaf_size=70, n_neighbors=12, weights='distance')
#
#  KNeighborsClassifier(leaf_size=70, n_neighbors=12, weights='distance')
# {'1': {'precision': 0.45394736842105265, 'recall': 0.1140495867768595, 'f1-score': 0.18229854689564068, 'support': 605}, '2': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 429}, '3': {'precision': 0.7583333333333333, 'recall': 0.9817936614969656, 'f1-score': 0.8557155451072582, 'support': 2966}, 'accuracy': 0.74525, 'macro avg': {'precision': 0.404093567251462, 'recall': 0.36528108275794163, 'f1-score': 0.3460046973342996, 'support': 4000}, 'weighted avg': {'precision': 0.6309637061403509, 'recall': 0.74525, 'f1-score': 0.6620857319149976, 'support': 4000}}
# length of 3 3840 8 152
# -------       labels   category
# 0          3  Predicted
# 1          3  Predicted
# 2          3  Predicted
# 3          3  Predicted
# 4          3  Predicted
# ...      ...        ...
# 7995       3     Actual
# 7996       3     Actual
# 7997       3     Actual
# 7998       3     Actual
# 7999       3     Actual
#
# [8000 rows x 2 columns]
# Multinomial
# ----------
#
#  MultinomialNB(alpha=1)
# {'1': {'precision': 0.6527331189710611, 'recall': 0.33553719008264465, 'f1-score': 0.443231441048035, 'support': 605}, '2': {'precision': 0.23529411764705882, 'recall': 0.027972027972027972, 'f1-score': 0.049999999999999996, 'support': 429}, '3': {'precision': 0.7919186366135239, 'recall': 0.971341874578557, 'f1-score': 0.8725015142337977, 'support': 2966}, 'accuracy': 0.774, 'macro avg': {'precision': 0.5599819577438813, 'recall': 0.44495036421107653, 'f1-score': 0.4552443184272776, 'support': 4000}, 'weighted avg': {'precision': 0.7111688474109481, 'recall': 0.774, 'f1-score': 0.7193611282628762, 'support': 4000}}
# length of 3 3638 51 311
# -------       labels   category
# 0          3  Predicted
# 1          3  Predicted
# 2          3  Predicted
# 3          3  Predicted
# 4          3  Predicted
# ...      ...        ...
# 7995       3     Actual
# 7996       3     Actual
# 7997       3     Actual
# 7998       3     Actual
# 7999       3     Actual
#
# [8000 rows x 2 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Users/ifeoluwaking/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
